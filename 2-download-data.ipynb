# %% [markdown]
# yfinance (https://pypi.org/project/yfinance/) is an open-source toll
# that uses Yahoo's publicly available APIs to download finance data.
#
# GOOD FOR >30m resolution, but has LIMITATIONS for others:
#
# - Minute Data: 7 days
# - 2 Minute Data: 60 days
# - 5 Minute Data: 60 days
# - 15 Minute Data: 60 days
# - 30 Minute Data: 60 days
# - Hourly Data: 730 days
# - Daily/Weekly/Monthly: No limit
#
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#
# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#
# <!-- EXAMPLE USAGE:
#
# tickers = 'MA V'
# start = '2011-12-30'
# end = '2022-01-01'
# data = pd.DataFrame()
# data = yf.download(tickers, start, end)['Close']
# data
# yf.Ticker("MA").calendar # next event
# yf.Ticker("MA").earnings_dates # historical events
# yf.Ticker("MA").recommendations # grades
# yf.Ticker("MA").actions # dividends & splits -->

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pathlib import Path

# define data path
Path("data").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### GET TICKER NAMES

# %%
# get dataframe from the previous step
df = pd.read_pickle("pairs_to_download.pkl")

tickerStrings = list(df.index.union(df.columns))
tickerStrings
# Out:
# ['APO',
#  'BAC',
#  'BAM',
#  'BEN',
#  'BX',
#  'C',
#  'CADE',
#  'CG',
#  'COF',
#  'JHG',
#  'KKR',
#  'MS',
#  'RF',
#  'SCHW',
#  'STT',
#  'TROW',
#  'TW',
#  'USB']

# %% [markdown]
# ### DOWNLOAD & CREATE CSV FILE

# %% [markdown]
# #### SETUP

# %%
int_per = {'1d':'1y', '1h':'1y'}  # define interval and corresponding period

# %% [markdown]
# #### OPTION 1 (DOWNLOAD  & CREATE A FILE FOR EACH TICKER PER INTERVAL)

# %%
# int_per = {'1d':'3mo', '1h':'3mo'}  # define interval and corresponding period


# enable to enter manually
#tickerStrings = ['MA', 'V', 'LNT', 'FTS', 'POR', 'CMS', 'OUT', 'WELL']

for ticker in tickerStrings:
    for key in int_per:
        data = yf.download(ticker, group_by="Ticker", period=int_per[key], interval=key)
        data['ticker'] = ticker
        data.set_index(data.columns[0]) # datetime row comes with different names or unnamed
        data.index.names = ['time']
    
        # use in need of sorting and renaming
        #data = data.set_index(["time"]).sort_index()
        #data = data.rename(columns={"Date": "time"})

        # save as seperate files
        data.to_csv(f'data/{ticker}_{key.upper()}.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Check if downloaded correctly:

# %%
filename = 'data/' +  tickerStrings[0] + '_1H.csv'
df = pd.read_csv(filename, parse_dates=["time"])
df
# Out:
#                            time       Open       High        Low      Close  \
# 0     2021-11-01 09:30:00-04:00  77.620003  78.010002  76.379997  76.514999
# 1     2021-11-01 10:30:00-04:00  76.589996  76.889999  75.849998  75.910004
# 2     2021-11-01 11:30:00-04:00  76.260002  76.370003  75.570000  76.080002
# 3     2021-11-01 12:30:00-04:00  75.739998  76.639999  75.650002  76.559998
# 4     2021-11-01 13:30:00-04:00  76.324997  76.639999  76.139999  76.290001
# ...                         ...        ...        ...        ...        ...
# 1757  2022-10-31 11:30:00-04:00  55.432499  55.930000  55.410000  55.820000
# 1758  2022-10-31 12:30:00-04:00  55.810001  55.959999  55.549999  55.950001
# 1759  2022-10-31 13:30:00-04:00  55.990002  56.000000  55.639999  55.639999
# 1760  2022-10-31 14:30:00-04:00  55.639999  55.830002  55.595001  55.700001
# 1761  2022-10-31 14:57:26-04:00  55.660801  55.660801  55.660801  55.660801
#
#       Adj Close  Volume ticker
# 0     76.514999  799831    APO
# 1     75.910004  823608    APO
# 2     76.080002  722579    APO
# 3     76.559998  641080    APO
# 4     76.290001  675032    APO
# ...         ...     ...    ...
# 1757  55.820000  326874    APO
# 1758  55.950001  275487    APO
# 1759  55.639999  167958    APO
# 1760  55.700001   90865    APO
# 1761  55.660801       0    APO
#
# [1762 rows x 8 columns]

# %% [markdown]
# #### OPTION 2 (DOWNLOAD  & CREATE SINGLE DF FROM ALL TICKERS)

# %%
# int_per = {'1d':'1y', '1h':'1y'}  # define interval and corresponding period

df_list = list()

for key in int_per:
    for ticker in tickerStrings:
        data = yf.download(ticker, group_by="Ticker", period=int_per[key], interval=key)
        data['ticker'] = ticker
        data.index.names = ['time']
        df_list.append(data)

    # combine all dataframes into a single dataframe
    df = pd.concat(df_list)

    # save to csv
    df.to_csv('data/tickers_'+key.upper()+'.csv')
    
    df_list = []
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Check if downloaded correctly:

# %%
filename = 'data/tickers_1H.csv'
df = pd.read_csv(filename, parse_dates=["time"])

# %%
df_c = df.set_index(["ticker", "time"]).sort_index() # set indexes
df_c
df_c.xs(tickerStrings[0]) # check the first ticker
# Out:
#                                 Open       High        Low      Close  \
# time
# 2021-11-01 09:30:00-04:00  77.620003  78.010002  76.379997  76.514999
# 2021-11-01 10:30:00-04:00  76.589996  76.889999  75.849998  75.910004
# 2021-11-01 11:30:00-04:00  76.260002  76.370003  75.570000  76.080002
# 2021-11-01 12:30:00-04:00  75.739998  76.639999  75.650002  76.559998
# 2021-11-01 13:30:00-04:00  76.324997  76.639999  76.139999  76.290001
# ...                              ...        ...        ...        ...
# 2022-10-31 11:30:00-04:00  55.432499  55.930000  55.410000  55.820000
# 2022-10-31 12:30:00-04:00  55.810001  55.959999  55.549999  55.950001
# 2022-10-31 13:30:00-04:00  55.990002  56.000000  55.639999  55.639999
# 2022-10-31 14:30:00-04:00  55.639999  55.830002  55.595001  55.700001
# 2022-10-31 14:57:42-04:00  55.639999  55.639999  55.639999  55.639999
#
#                            Adj Close  Volume
# time
# 2021-11-01 09:30:00-04:00  76.514999  799831
# 2021-11-01 10:30:00-04:00  75.910004  823608
# 2021-11-01 11:30:00-04:00  76.080002  722579
# 2021-11-01 12:30:00-04:00  76.559998  641080
# 2021-11-01 13:30:00-04:00  76.290001  675032
# ...                              ...     ...
# 2022-10-31 11:30:00-04:00  55.820000  326874
# 2022-10-31 12:30:00-04:00  55.950001  275487
# 2022-10-31 13:30:00-04:00  55.639999  167958
# 2022-10-31 14:30:00-04:00  55.700001   90865
# 2022-10-31 14:57:42-04:00  55.639999       0
#
# [1762 rows x 6 columns]

# %% [markdown]
# #### EXERCISE (DOWNLOAD MULTIPLE TICKERS AND FLATTEN THE LEVELS )

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "OUT WELL",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "1mo",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "30m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = False,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#                                 WELL                                           \
#                                 Open       High        Low      Close  Volume
# Datetime
# 2022-09-30 14:30:00-04:00  64.309998  64.334999  64.209999  64.209999       0
# 2022-09-30 15:00:00-04:00  64.209999  64.440002  64.150002  64.440002  208633
# 2022-09-30 15:30:00-04:00  64.440002  64.665001  64.279999  64.330002  554969
# 2022-10-03 09:30:00-04:00  65.099998  65.300003  63.849998  64.169998  256361
# 2022-10-03 10:00:00-04:00  64.220001  65.029999  64.180000  64.995003  222513
# ...                              ...        ...        ...        ...     ...
# 2022-10-31 12:30:00-04:00  61.180000  61.240002  61.000000  61.055000  117275
# 2022-10-31 13:00:00-04:00  61.040001  61.189999  60.965000  61.189999   92784
# 2022-10-31 13:30:00-04:00  61.189999  61.240002  61.049999  61.095001   79221
# 2022-10-31 14:00:00-04:00  61.099998  61.209999  61.060001  61.150002   53796
# 2022-10-31 14:30:00-04:00  61.139999  61.348301  61.119999  61.299999   66435
#
#                                  OUT
#                                 Open       High        Low      Close  Volume
# Datetime
# 2022-09-30 14:30:00-04:00  15.190000  15.190000  15.150000  15.160000       0
# 2022-09-30 15:00:00-04:00  15.160000  15.295000  15.145000  15.295000  153201
# 2022-09-30 15:30:00-04:00  15.300000  15.330000  15.170000  15.190000  378534
# 2022-10-03 09:30:00-04:00  15.520000  15.540000  15.010000  15.100000   70525
# 2022-10-03 10:00:00-04:00  15.140000  15.470000  15.120000  15.450000   83731
# ...                              ...        ...        ...        ...     ...
# 2022-10-31 12:30:00-04:00  18.459999  18.510000  18.400000  18.440001   54625
# 2022-10-31 13:00:00-04:00  18.455000  18.455000  18.299999  18.320000   84271
# 2022-10-31 13:30:00-04:00  18.309999  18.340000  18.250000  18.280001  102875
# 2022-10-31 14:00:00-04:00  18.275000  18.299999  18.170000  18.184999  119722
# 2022-10-31 14:30:00-04:00  18.180000  18.245001  18.129999  18.135000  145611
#
# [274 rows x 10 columns]

# %% [markdown]
# to flatten the MultiIndex use map with join:

# %%
data_flat = data.copy()
data_flat.columns = data_flat.columns.map('_'.join)
data_flat =data_flat.reset_index()
data_flat
# Out:
#                      Datetime  WELL_Open  WELL_High   WELL_Low  WELL_Close  \
# 0   2022-09-30 14:30:00-04:00  64.309998  64.334999  64.209999   64.209999
# 1   2022-09-30 15:00:00-04:00  64.209999  64.440002  64.150002   64.440002
# 2   2022-09-30 15:30:00-04:00  64.440002  64.665001  64.279999   64.330002
# 3   2022-10-03 09:30:00-04:00  65.099998  65.300003  63.849998   64.169998
# 4   2022-10-03 10:00:00-04:00  64.220001  65.029999  64.180000   64.995003
# ..                        ...        ...        ...        ...         ...
# 269 2022-10-31 12:30:00-04:00  61.180000  61.240002  61.000000   61.055000
# 270 2022-10-31 13:00:00-04:00  61.040001  61.189999  60.965000   61.189999
# 271 2022-10-31 13:30:00-04:00  61.189999  61.240002  61.049999   61.095001
# 272 2022-10-31 14:00:00-04:00  61.099998  61.209999  61.060001   61.150002
# 273 2022-10-31 14:30:00-04:00  61.139999  61.348301  61.119999   61.299999
#
#      WELL_Volume   OUT_Open   OUT_High    OUT_Low  OUT_Close  OUT_Volume
# 0              0  15.190000  15.190000  15.150000  15.160000           0
# 1         208633  15.160000  15.295000  15.145000  15.295000      153201
# 2         554969  15.300000  15.330000  15.170000  15.190000      378534
# 3         256361  15.520000  15.540000  15.010000  15.100000       70525
# 4         222513  15.140000  15.470000  15.120000  15.450000       83731
# ..           ...        ...        ...        ...        ...         ...
# 269       117275  18.459999  18.510000  18.400000  18.440001       54625
# 270        92784  18.455000  18.455000  18.299999  18.320000       84271
# 271        79221  18.309999  18.340000  18.250000  18.280001      102875
# 272        53796  18.275000  18.299999  18.170000  18.184999      119722
# 273        66435  18.180000  18.245001  18.129999  18.135000      145611
#
# [274 rows x 11 columns]

# %% [markdown]
# or use index values to get the data

# %% [markdown]
# save as a file

# %%
multiindex = data.columns
ticker_list = set([item[0] for item in multiindex])

for ticker in ticker_list:
    data_i = data[(ticker, 'Close')].reset_index().droplevel(level=0, axis=1)
    data_i = data_i.rename(columns={ data_i.columns[0]: "time" })
    data_i = data_i.set_index(["time"]).sort_index()
    #save as seperate files
    data_i.to_csv(f'data/ticker_{ticker}.csv')
